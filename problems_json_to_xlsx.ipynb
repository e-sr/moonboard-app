# %%
import pandas as pd
import json

# %%
contest = json.load(open('moonBoardApp/favorites/contest.json','r+'))

# %%
df = pd.DataFrame(contest).T.sort_values('grade').reset_index().drop(['index','site_id','author'],axis=1)

# %%
df
# Out:
#    grade                       name
# 0    6b+                      Choss
# 1    6b+           Warm Up!! (Easy)
# 2    6b+                     2 Easy
# 3    6b+         Jokin' about (JKN)
# 4    6b+            Ella's Easy One
# 5    6b+              turtleheadin’
# 6    6b+              AAGGGGGGGH!😣😥
# 7    6b+            2 pinch pimpin'
# 8    6b+                 TCA Comp 1
# 9    6b+                  Easy pogo
# 10   6b+               AF easy four
# 11   6b+              easy.herzchen
# 12    6c                 Pronti via
# 13    6c                      Byron
# 14    6c               Yellow Chair
# 15    6c            Procrastination
# 16    6c              Mr short dyno
# 17    6c             Martin special
# 18    6c          40 Year Old Fatty
# 19    6c                Californian
# 20   6c+               Static Cling
# 21   6c+              Shaolin Style
# 22   6c+             The Gravel Pit
# 23   6c+     System Board Doubles 1
# 24   6c+                   Puke Boy
# ...

# %%
df.to_excel('problemi_contest.xlsx')
